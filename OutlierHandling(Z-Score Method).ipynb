# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp

# %%
# !pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in c:\programdata\anaconda3\lib\site-packages (from scipy) (1.26.4)

# %%
from scipy.stats import zscore
import pandas as pd

# %%
data = {
    'value':[10,12,12,13,12,11,14,100,10,12,12,13,12,11,14,10,12,12,13,12,11,14,50]
}
df = pd.DataFrame(data)
df
# Out:
#     value
# 0      10
# 1      12
# 2      12
# 3      13
# 4      12
# 5      11
# 6      14
# 7     100
# 8      10
# 9      12
# 10     12
# 11     13
# 12     12
# 13     11
# 14     14
# 15     10
# 16     12
# 17     12
# 18     13
# 19     12
# 20     11
# 21     14
# 22     50

# %%
df['zscore'] = zscore(df['value'])
df
threshold = 3
df['outlier'] = np.abs(df['zscore']) > threshold
df
# Out:
#     value    zscore  outlier
# 0      10 -0.388372    False
# 1      12 -0.284505    False
# 2      12 -0.284505    False
# 3      13 -0.232571    False
# 4      12 -0.284505    False
# 5      11 -0.336438    False
# 6      14 -0.180638    False
# 7     100  4.285637     True
# 8      10 -0.388372    False
# 9      12 -0.284505    False
# 10     12 -0.284505    False
# 11     13 -0.232571    False
# 12     12 -0.284505    False
# 13     11 -0.336438    False
# 14     14 -0.180638    False
# 15     10 -0.388372    False
# 16     12 -0.284505    False
# 17     12 -0.284505    False
# 18     13 -0.232571    False
# 19     12 -0.284505    False
# 20     11 -0.336438    False
# 21     14 -0.180638    False
# 22     50  1.688965    False

# %%
plt.figure(figsize = (12,6))
plt.subplot(1,2,1)
sns.boxplot(y = df['value'])
plt.title("Before Removing Outliers")
# Out:
# Text(0.5, 1.0, 'Before Removing Outliers')

# %%
df_clean = df[df['outlier']==False]
df_clean
# Out:
#     value    zscore  outlier
# 0      10 -0.388372    False
# 1      12 -0.284505    False
# 2      12 -0.284505    False
# 3      13 -0.232571    False
# 4      12 -0.284505    False
# 5      11 -0.336438    False
# 6      14 -0.180638    False
# 8      10 -0.388372    False
# 9      12 -0.284505    False
# 10     12 -0.284505    False
# 11     13 -0.232571    False
# 12     12 -0.284505    False
# 13     11 -0.336438    False
# 14     14 -0.180638    False
# 15     10 -0.388372    False
# 16     12 -0.284505    False
# 17     12 -0.284505    False
# 18     13 -0.232571    False
# 19     12 -0.284505    False
# 20     11 -0.336438    False
# 21     14 -0.180638    False
# 22     50  1.688965    False

# %%
sns.boxplot(df_clean['value'])
# Out:
# <Axes: >
